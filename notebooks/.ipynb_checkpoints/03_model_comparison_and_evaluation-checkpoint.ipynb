# %% [markdown]
# # 03 — Full RAG Evaluation, Plots, and Failure Inspection
#
# This notebook evaluates the full RAG system with the production retrieval profile.
#
# It performs:
# 1. retrieval ablation refresh
# 2. abstention precision evaluation (score-gate behavior on out-of-scope queries)
# 3. generation evaluation with `hybrid_rerank`
# 4. automatic plot generation
# 5. failure inspection and error breakdown

# %%
from pathlib import Path
import sys
import pandas as pd
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud

# %%
from scripts.config import (
    EVAL_DIR,
    PLOTS_DIR,
    LLM_MODEL,
    JUDGE_MODEL,
    RESULTS_RETRIEVAL_FILE,
    RESULTS_GENERATION_FILE,
    RESULTS_SUMMARY_FILE,
    RESULTS_FAILURES_FILE,
    RESULTS_ABLATION_FILE,
    RESULTS_ABSTENTION_FILE,
    EXPERIMENT_MANIFEST_FILE,
    RETRIEVAL_PROFILES,
    save_experiment_manifest,
)
# --- UPDATED IMPORT ---
from scripts.retriever import load_retrieval_assets, retrieve_documents
import scripts.eval as eval_mod

retrieval_gold = eval_mod.load_json(EVAL_DIR / "retrieval_gold.json")
qa_gold = eval_mod.load_json(EVAL_DIR / "qa_gold.json")

abstention_path = EVAL_DIR / "abstention_gold.json"
abstention_gold = eval_mod.load_json(abstention_path) if abstention_path.exists() else []

print("retrieval_gold :", len(retrieval_gold))
print("qa_gold        :", len(qa_gold))
print("abstention_gold:", len(abstention_gold))
# Out:
# retrieval_gold : 17
# qa_gold        : 17
# abstention_gold: 3

# %% [markdown]
# ## Build retriever and save experiment manifest

# %%
TARGET_PROFILE = "hybrid_rerank"

# Save the hyperparameter manifest for tracking
save_experiment_manifest(EXPERIMENT_MANIFEST_FILE)

print("Pipeline ready for profile:", TARGET_PROFILE)
print("Manifest saved to:", EXPERIMENT_MANIFEST_FILE)
# Out:
# Pipeline ready for profile: hybrid_rerank
# Manifest saved to: C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\experiment_manifest.json

# %% [markdown]
# ## Refresh retrieval ablation and plots

# %%
from scripts.retriever import load_retrieval_assets
import pandas as pd

print("Loading functional retrieval assets into memory...")
assets = load_retrieval_assets()

print("Running retrieval ablation study...")
ablation_results = [
    eval_mod.evaluate_retrieval_profile(retrieval_gold, profile_name, assets)
    for profile_name in RETRIEVAL_PROFILES.keys()
]

eval_mod.save_json(ablation_results, RESULTS_ABLATION_FILE)
eval_mod.plot_retrieval_profiles(ablation_results, PLOTS_DIR)

ablation_df = pd.DataFrame([
    {"profile_name": item["profile_name"], **item["aggregate"]}
    for item in ablation_results
]).sort_values(["ndcg@5", "recall@5"], ascending=False)

print("Saved ablation results →", RESULTS_ABLATION_FILE)
ablation_df
# Out:
# Loading functional retrieval assets into memory...
# Running retrieval ablation study...
# Saved ablation results → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_ablation.json
#     profile_name  recall@5  recall@10    ndcg@5       mrr         qps  \
# 1         hybrid  0.686275   0.686275  0.700669  0.794118   15.769631
# 0  hybrid_rerank  0.656863   0.656863  0.638169  0.715686   12.237802
# 2     dense_only  0.686275   0.686275  0.589996  0.642157   16.445332
# 3      bm25_only  0.666667   0.666667  0.557646  0.560784  530.287197
#
#    avg_latency_sec
# 1         0.063413
# 0         0.081714
# 2         0.060808
# 3         0.001886

# %% [markdown]
# ## Refresh abstention precision
#
# Score-gate behavior on out-of-scope queries — measured the same way `run_rag.py::should_abstain()` does at inference time, so prod and eval can't drift.

# %%
if abstention_gold:
    print("Running abstention evaluation...")
    abstention_results = [
        # PASS ASSETS HERE:
        eval_mod.evaluate_abstention(abstention_gold, profile_name, assets)
        for profile_name in RETRIEVAL_PROFILES.keys()
    ]
    eval_mod.save_json(abstention_results, RESULTS_ABSTENTION_FILE)

    abstention_df = pd.DataFrame([
        {"profile_name": item["profile_name"], **item["aggregate"]}
        for item in abstention_results
    ])
    
    print("Saved abstention results →", RESULTS_ABSTENTION_FILE)
    display(abstention_df)
else:
    print("abstention_gold.json not found — skipping abstention eval.")
    abstention_results = []
# Out:
# Running abstention evaluation...
# Saved abstention results → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_abstention.json
#     profile_name  abstention_precision  num_correct  num_applicable  \
# 0  hybrid_rerank                   1.0            3               3
# 1         hybrid                   0.0            0               3
# 2     dense_only                   NaN            0               0
# 3      bm25_only                   NaN            0               0
#
#    num_total  avg_latency_sec
# 0          3         0.139492
# 1          3         0.060217
# 2          3         0.056489
# 3          3         0.001518

# %% [markdown]
# ## Evaluate generation with `hybrid_rerank`

# %%
best_retrieval = next(x for x in ablation_results if x["profile_name"] == TARGET_PROFILE)

print(f"Running LLM generation & Ragas evaluation for {TARGET_PROFILE}...")
generation_results = eval_mod.evaluate_generation(
    qa_gold=qa_gold,
    assets=assets,           # <-- This is the crucial functional update!
    model_name=LLM_MODEL,
    judge_model=JUDGE_MODEL,
    profile_name=TARGET_PROFILE,
    request_timeout=300,
    ragas_retries=2,
    skip_ragas=False,
)

failures = eval_mod.build_failure_report(qa_gold, retrieval_gold, generation_results)
summary_rows = eval_mod.build_summary_rows(best_retrieval, generation_results)

eval_mod.save_json(best_retrieval, RESULTS_RETRIEVAL_FILE)
eval_mod.save_json(generation_results, RESULTS_GENERATION_FILE)
eval_mod.save_json(failures, RESULTS_FAILURES_FILE)
eval_mod.save_summary_csv(summary_rows, RESULTS_SUMMARY_FILE)

print("Saved retrieval results →", RESULTS_RETRIEVAL_FILE)
print("Saved generation results →", RESULTS_GENERATION_FILE)
print("Saved failures →", RESULTS_FAILURES_FILE)
print("Saved summary →", RESULTS_SUMMARY_FILE)

display(pd.DataFrame(summary_rows))
# Out:
# Running LLM generation & Ragas evaluation for hybrid_rerank...
# C:\Users\aminl\anaconda3\envs\pytorch-gpu\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Evaluating:   0%|          | 0/51 [00:00<?, ?it/s]
# Saved retrieval results → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_retrieval.json
# Saved generation results → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_generation.json
# Saved failures → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_failures.json
# Saved summary → C:\Users\aminl\Desktop\PORTFOLIO Projects\final list of projects\aegis-rag - fraud\data\eval\results_summary.csv
#     model_name  judge_model   profile_name  retrieval_recall@5  \
# 0  llama3.1:8b  llama3.1:8b  hybrid_rerank            0.656863
#
#    retrieval_recall@10  retrieval_ndcg@5  retrieval_mrr  retrieval_qps  \
# 0             0.656863          0.638169       0.715686      12.237802
#
#    retrieval_avg_latency_sec  generation_faithfulness  ...  \
# 0                   0.081714                 0.866036  ...
#
#    generation_exact_match  generation_semantic_match  \
# 0                     0.0                   0.851682
#
#    generation_avg_latency_sec  generation_avg_tokens_per_answer_est  \
# 0                    2.221671                             98.941176
#
#    generation_avg_top_rerank_score  generation_avg_top_fused_score  \
# 0                             None                            None
#
#   generation_qps num_examples  num_ragas_missing  ragas_error
# 0       0.450112           17                  0         None
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Generated plots

# %%
display(Image(filename=str(PLOTS_DIR / "retrieval_profile_ndcg.png")))
display(Image(filename=str(PLOTS_DIR / "retrieval_profile_recall.png")))
display(Image(filename=str(PLOTS_DIR / "latency_quality_tradeoff.png")))

# %% [markdown]
# ## Failure breakdown

# %%
failures_df = pd.DataFrame(failures)
failures_df["error_type"].value_counts().rename_axis("error_type").reset_index(name="count")
# Out:
#        error_type  count
# 0         correct     14
# 1  retrieval_miss      3

# %% [markdown]
# ## Inspect non-correct cases

# %%
non_correct_df = failures_df[failures_df["error_type"] != "correct"].copy()
non_correct_df[[
    "id", "question", "error_type", "ground_truth", "answer", "faithfulness", "semantic_match"
]].head(20)
# Out:
#     id                                           question      error_type  \
# 9    9               What does OSFI Guideline E-21 cover?  retrieval_miss
# 13  13          What is the scope of OSFI Guideline B-13?  retrieval_miss
# 14  14  What are the cyber-security capabilities outli...  retrieval_miss
#
#                                          ground_truth  \
# 9   OSFI Guideline E-21 sets expectations for fede...
# 13  OSFI Guideline B-13 establishes expectations f...
# 14  B-13's cyber security domain is organized arou...
#
#                                                answer  faithfulness  \
# 9   OSFI Guideline E-21 covers Operational Risk Ma...         1.000
# 13  The scope of OSFI Guideline B-13 is Technology...         0.875
# 14  According to Guideline B-13: Technology and Cy...         1.000
#
#     semantic_match
# 9         0.871761
# 13        0.922288
# 14        0.493035

# %% [markdown]
# ## Deep dive by error type

# %%
error_type = "generation_hallucination"
subset = failures_df[failures_df["error_type"] == error_type][[
    "id", "question", "ground_truth", "answer", "retrieved_ids", "relevant_ids"
]]
print("Rows for", error_type, ":", len(subset))
subset.head(10)
# Out:
# Rows for generation_hallucination : 0
# Empty DataFrame
# Columns: [id, question, ground_truth, answer, retrieved_ids, relevant_ids]
# Index: []

# %% [markdown]
# ## Review aggregate metrics

# %%
generation_results['aggregate']
# Out:
# {'faithfulness': 0.8660364145658264,
#  'answer_relevancy': 0.9602574776438995,
#  'context_precision': 0.907924836577675,
#  'exact_match': 0.0,
#  'semantic_match': 0.8516818109680625,
#  'avg_latency_sec': 2.22167052941158,
#  'avg_tokens_per_answer_est': 98.94117647058823,
#  'avg_top_rerank_score': None,
#  'avg_top_fused_score': None,
#  'qps': 0.45011174553629907,
#  'num_examples': 17,
#  'num_ragas_missing': 0}

# %% [markdown]
# ## Suggested workflow
#
# - run `01_data_ingestion_and_chunking.ipynb` after updating PDFs
# - run `02_hybrid_retrieval_baseline.ipynb` to compare retrieval profiles and abstention precision
# - run this notebook with `TARGET_PROFILE = "hybrid"` for the full production evaluation
# - inspect `results_failures.json` whenever quality drops
# - inspect `results_abstention.json` whenever the abstention behavior changes
